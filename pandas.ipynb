# %%
import pandas as pd

# %%
data=pd.read_csv('car.csv')

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.head(8)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0
# ...

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
data.tail(9)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 292     jazz  2016           6.40           8.40       12000    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 292      Dealer       Manual      0
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# 295      Dealer       Manual      0
# 296      Dealer       Manual      0
# ...

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.sample()
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 185  Suzuki Access 125  2008           0.25           0.58        1900
#
#     Fuel_Type Seller_Type Transmission  Owner
# 185    Petrol  Individual    Automatic      0

# %%
data.sample(6)
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 48              ertiga  2015           5.80           7.71       25870
# 94       corolla altis  2008           4.00          22.78       89000
# 133  Bajaj Avenger 220  2016           0.72           0.95         500
# 177   Honda Activa 125  2016           0.35           0.57       24000
# 253               city  2014           7.20           9.90       48000
# 227                i10  2011           2.55           4.43       57000
#
#     Fuel_Type Seller_Type Transmission  Owner
# 48     Petrol      Dealer       Manual      0
# 94     Petrol      Dealer    Automatic      0
# 133    Petrol  Individual       Manual      0
# 177    Petrol  Individual    Automatic      0
# 253    Diesel      Dealer       Manual      0
# 227    Petrol      Dealer       Manual      0

# %%
data['Car_Name']
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data2=data[['Selling_Price', 'Present_Price', 'Kms_Driven']]

# %%
data2
# Out:
#      Selling_Price  Present_Price  Kms_Driven
# 0             3.35           5.59       27000
# 1             4.75           9.54       43000
# 2             7.25           9.85        6900
# 3             2.85           4.15        5200
# 4             4.60           6.87       42450
# ..             ...            ...         ...
# 296           9.50          11.60       33988
# 297           4.00           5.90       60000
# 298           3.35          11.00       87934
# 299          11.50          12.50        9000
# 300           5.30           5.90        5464
#
# [301 rows x 3 columns]

# %%
data['Kms_Driven']
# Out:
# 0      27000
# 1      43000
# 2       6900
# 3       5200
# 4      42450
#        ...
# 296    33988
# 297    60000
# 298    87934
# 299     9000
# 300     5464
# Name: Kms_Driven, Length: 301, dtype: int64

# %%
data.shape
# Out:
# (301, 9)

# %%
data.size
# Out:
# 2709

# %%
data3=data[data['Kms_Driven']>50000]

# %%
data3
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 11      ciaz  2015           6.85          10.38       51000    Diesel
# 14     dzire  2009           2.25           7.21       77427    Petrol
# 24   wagon r  2013           2.90           4.41       56879    Petrol
# 26     swift  2013           4.15           5.87       55138    Petrol
# 30      ritz  2012           3.10           5.98       51439    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 281     city  2006           2.10           7.60       50456    Petrol
# 282     city  2014           8.25          14.00       63000    Diesel
# 295     city  2015           8.55          13.09       60076    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
#
#     Seller_Type Transmission  Owner
# 11       Dealer       Manual      0
# 14       Dealer       Manual      0
# ...

# %%
data_order=data.sort_values(by='Present_Price')

# %%
data_order
# Out:
#                    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 195           Bajaj  ct 100  2015           0.18           0.32       35000
# 183      Bajaj Discover 100  2013           0.27           0.47       21000
# 181      Hero Splender Plus  2016           0.30           0.48       50000
# 187        Honda CB twister  2013           0.25           0.51       32000
# 180  Hero Honda Passion Pro  2012           0.30           0.51       60000
# ..                      ...   ...            ...            ...         ...
# 59                 fortuner  2014          19.99          35.96       41000
# 63                 fortuner  2015          23.50          35.96       47000
# 62                 fortuner  2014          18.75          35.96       78000
# 64                 fortuner  2017          33.00          36.23        6000
# 86             land cruiser  2010          35.00          92.60       78000
#
#     Fuel_Type Seller_Type Transmission  Owner
# ...

# %%
data_fuel_type_diesel=data[data['Fuel_Type']=='Diesel']

# %%
data_sort_desc=data.sort_values(by='Present_Price',ascending=False)

# %%
data_sort_desc
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 86         land cruiser  2010          35.00          92.60       78000
# 64             fortuner  2017          33.00          36.23        6000
# 59             fortuner  2014          19.99          35.96       41000
# 62             fortuner  2014          18.75          35.96       78000
# 63             fortuner  2015          23.50          35.96       47000
# ..                  ...   ...            ...            ...         ...
# 197    Honda CB twister  2010           0.16           0.51       33000
# 173           Activa 4g  2017           0.40           0.51        1300
# 181  Hero Splender Plus  2016           0.30           0.48       50000
# 183  Bajaj Discover 100  2013           0.27           0.47       21000
# 195       Bajaj  ct 100  2015           0.18           0.32       35000
#
#     Fuel_Type Seller_Type Transmission  Owner
# 86     Diesel      Dealer       Manual      0
# ...

# %%
data['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data_group=data.groupby('Transmission')

# %%
data_group

# %%
data_group_Car_Name=data.groupby(['Car_Name'])

# %%
data_group_Car_Name.first()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# 800                2003           0.35           2.28      127000    Petrol
# Activa 3g          2016           0.45           0.54         500    Petrol
# Activa 4g          2017           0.40           0.51        1300    Petrol
# Bajaj  ct 100      2015           0.18           0.32       35000    Petrol
# Bajaj Avenger 150  2016           0.75           0.80        7000    Petrol
# ...                 ...            ...            ...         ...       ...
# sx4                2013           4.75           9.54       43000    Diesel
# verna              2012           4.50           9.40       36100    Petrol
# vitara brezza      2018           9.25           9.83        2071    Diesel
# wagon r            2011           2.85           4.15        5200    Petrol
# xcent              2017           5.75           7.13       12479    Petrol
#
# ...

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# ## pivot table

# %%
data.pivot_table(index='Seller_Type',columns='Fuel_Type',values='Kms_Driven')
# Out:
# Fuel_Type        CNG         Diesel        Petrol
# Seller_Type
# Dealer       42749.0   48935.508475  35806.589552
# Individual       NaN  135000.000000  30622.219048

# %% [markdown]
# ## handling missing values

# %%
data.dropna()  #it shows any row or column is empty or not
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data.fillna(value=10) #if any row or column is empty then fill wth 10. na stands for not available
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
#data.fillna(data.mean())  #only the condition is that all the value should be numerical
#data.fillna(data.mode())  #only the condition is that all the value should be numerical

# %%
#to show particular rows and column
data.iloc[2:5,5:9]
# Out:
#   Fuel_Type Seller_Type Transmission  Owner
# 2    Petrol      Dealer       Manual      0
# 3    Petrol      Dealer       Manual      0
# 4    Diesel      Dealer       Manual      0

# %%
data.loc[(data['Car_Name']=='ciaz') & (data['Selling_Price']>7.25)]
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 8      ciaz  2016           8.75           8.89       20273    Diesel
# 9      ciaz  2015           7.45           8.92       42367    Diesel
# 12     ciaz  2015           7.50           9.94       15000    Petrol
# 29     ciaz  2015           7.45          10.38       45000    Diesel
# 45     ciaz  2014           7.50          12.04       15000    Petrol
# 49     ciaz  2017           7.75           9.29       37000    Petrol
#
#    Seller_Type Transmission  Owner
# 8       Dealer       Manual      0
# 9       Dealer       Manual      0
# 12      Dealer    Automatic      0
# 29      Dealer       Manual      0
# 45      Dealer    Automatic      0
# 49      Dealer    Automatic      0

# %%
#for multiply any specific value with any particular row
data_multiply=data['Selling_Price'].apply(lambda x:x*100)

# %%
data_multiply
# Out:
# 0       335.0
# 1       475.0
# 2       725.0
# 3       285.0
# 4       460.0
#         ...
# 296     950.0
# 297     400.0
# 298     335.0
# 299    1150.0
# 300     530.0
# Name: Selling_Price, Length: 301, dtype: float64

# %%
data.to_excel('output.xlsx',sheet_name='final_file')
